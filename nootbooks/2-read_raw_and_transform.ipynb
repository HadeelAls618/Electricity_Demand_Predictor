# %%
from src.component.data_info import *
from src.paths import *
import pandas as pd

# %%
#1-load electricity data for a year
start_date = datetime(2024, 1, 1)  # Replace with your desired start date
end_date = datetime(2025, 1, 7)    # Replace with your desired end date


electricity_data=load_daily_electricity_data(start_date,end_date)
# Out:
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-01-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-02-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-03-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-04-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-05-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-06-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-07-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-08-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-09-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-10-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-11-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-07.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-08.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-09.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-10.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-11.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-12.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-13.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-14.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-15.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-16.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-17.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-18.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-19.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-20.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-21.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-22.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-23.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-24.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-25.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-26.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-27.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-28.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-29.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-30.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2024-12-31.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-01.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-02.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-03.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-04.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-05.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-06.json
# Loading file D:\Electricity_demand_predictor2\data\raw\electricity_raw_data\hourly_demand_2025-01-07.json
# Successfully loaded and processed data for 2024-01-01 00:00:00 to 2025-01-07 00:00:00

# %%
electricity_data
# Out:
#                             date  sub_region_code demand
# 0      2024-01-02 00:00:00+00:00               53   9276
# 1      2024-01-02 00:00:00+00:00               59   8985
# 2      2024-01-02 00:00:00+00:00               61   1504
# 3      2024-01-02 00:00:00+00:00               67     55
# 4      2024-01-02 00:00:00+00:00               21  11427
# ...                          ...              ...    ...
# 771461 2025-01-07 00:00:00+00:00               64    525
# 771462 2025-01-07 00:00:00+00:00               65   4073
# 771463 2025-01-07 00:00:00+00:00               68   4587
# 771464 2025-01-07 00:00:00+00:00               70   1457
# 771465 2025-01-07 00:00:00+00:00               71   4460
#
# [771466 rows x 3 columns]

# %%
import openmeteo_requests

import requests_cache
import pandas as pd
from retry_requests import retry

# Setup the Open-Meteo API client with cache and retry on error
cache_session = requests_cache.CachedSession('.cache', expire_after = -1)
retry_session = retry(cache_session, retries = 5, backoff_factor = 0.2)
openmeteo = openmeteo_requests.Client(session = retry_session)

# Make sure all required weather variables are listed here
# The order of variables in hourly or daily is important to assign them correctly below
def fetch_weather_data(start_date, end_date):
	start_date = pd.to_datetime(start_date,  format="YYYY-MM-DD")
	end_date = pd.to_datetime(end_date,  format="YYYY-MM-DD")

	url = "https://archive-api.open-meteo.com/v1/archive"
	params = {
	"latitude": 52.52,
	"longitude": 13.41,
	"start_date": start_date,
	"end_date": end_date,
	"hourly": ["temperature_2m", "weather_code"],
	"timeformat": "unixtime",
	"timezone": "America/New_York"}
	responses = openmeteo.weather_api(url, params=params)

   # Process first location. Add a for-loop for multiple locations or weather models
	response = responses[0]
	print(f"Coordinates {response.Latitude()}°N {response.Longitude()}°E")
	print(f"Elevation {response.Elevation()} m asl")
	print(f"Timezone {response.Timezone()} {response.TimezoneAbbreviation()}")
	print(f"Timezone difference to GMT+0 {response.UtcOffsetSeconds()} s")

    # Process hourly data. The order of variables needs to be the same as requested.
	hourly = response.Hourly()
	hourly_temperature_2m = hourly.Variables(0).ValuesAsNumpy()
	hourly_weather_code = hourly.Variables(1).ValuesAsNumpy()

	hourly_data = {"date": pd.date_range(
		start = pd.to_datetime(hourly.Time(), unit = "s", utc = True),
		end = pd.to_datetime(hourly.TimeEnd(), unit = "s", utc = True),
		freq = pd.Timedelta(seconds = hourly.Interval()),
		inclusive = "left"
	)}

	hourly_data["temperature_2m"] = hourly_temperature_2m

	hourly_dataframe = pd.DataFrame(data = hourly_data)
	return hourly_dataframe

# %%
#read weather data
weather_data=fetch_weather_data(start_date,end_date)
weather_data
# Out:
# ---------------------------------------------------------------------------
# OpenMeteoRequestsError                    Traceback (most recent call last)
# Cell In[6], line 2
#       1 #read weather data
# ----> 2 weather_data=fetch_weather_data(start_date,end_date)
#       3 weather_data
#
# Cell In[5], line 24, in fetch_weather_data(start_date, end_date)
#      15 	url = "https://archive-api.open-meteo.com/v1/archive"
#      16 	params = {
#      17 	"latitude": 52.52,
#      18 	"longitude": 13.41,
#    (...)
#      22 	"timeformat": "unixtime",
#      23 	"timezone": "America/New_York"}
# ---> 24 	responses = openmeteo.weather_api(url, params=params)
#      26    # Process first location. Add a for-loop for multiple locations or weather models
#      27 	response = responses[0]
#
# File d:\poetry_virtualenvs\src-o1faXYQI-py3.12\Lib\site-packages\openmeteo_requests\Client.py:54, in Client.weather_api(self, url, params, method, verify)
#      50 def weather_api(
#      51     self, url: str, params: any, method: str = "GET", verify: bool | str | None = None
#      52 ) -> list[WeatherApiResponse]:
#      53     """Get and decode as weather api"""
# ---> 54     return self._get(WeatherApiResponse, url, params, method, verify)
#
# File d:\poetry_virtualenvs\src-o1faXYQI-py3.12\Lib\site-packages\openmeteo_requests\Client.py:35, in Client._get(self, cls, url, params, method, verify)
#      33 if response.status_code in [400, 429]:
#      34     response_body = response.json()
# ---> 35     raise OpenMeteoRequestsError(response_body)
#      37 response.raise_for_status()
#      39 data = response.content
#
# OpenMeteoRequestsError: {'error': True, 'reason': "Invalid date format. Make sure to use 'YYYY-MM-DD'"}

# %%
#merge them into full data frame
full_data=merge_data(electricity_data,weather_data)
full_data
# Out:
#                        date  sub_region_code demand  temperature_2m
# 0       2024-01-02 00:00:00               53   9276          4.8085
# 1       2024-01-02 00:00:00               59   8985          4.8085
# 2       2024-01-02 00:00:00               61   1504          4.8085
# 3       2024-01-02 00:00:00               67     55          4.8085
# 4       2024-01-02 00:00:00               21  11427          4.8085
# ...                     ...              ...    ...             ...
# 758601  2025-01-01 00:00:00               64    407          0.8085
# 758602  2025-01-01 00:00:00               65   3899          0.8085
# 758603  2025-01-01 00:00:00               68   4422          0.8085
# 758604  2025-01-01 00:00:00               70   1171          0.8085
# 758605  2025-01-01 00:00:00               71   3789          0.8085
#
# [758606 rows x 4 columns]

# %%
full_data.to_parquet(TRANSFORMED_DATA_DIR/f'full_data.parquet',index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_demand_trend(data, start_date, end_date, region_code):
    """
    Plots the demand trend for a specific region within a given date range.
    
    Parameters:
        data (pd.DataFrame): The dataframe containing the demand data.
        start_date (str): The start date for the plot in 'YYYY-MM-DD' format.
        end_date (str): The end date for the plot in 'YYYY-MM-DD' format.
        region_code (int): The sub_region_code to filter the data for plotting.
    """
    # Convert date column to datetime if it's not already
    if data['date'].dtype == object:
        data['date'] = pd.to_datetime(data['date'])
    
    # Filter data based on date range and region
    mask = (data['date'] >= start_date) & (data['date'] <= end_date) & (data['sub_region_code'] == region_code)
    filtered_data = data[mask]
    
    # Check if filtered data is empty
    if filtered_data.empty:
        print(f"No data available for Region {region_code} between {start_date} and {end_date}.")
        return
    
    # Plotting
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=filtered_data, x='date', y='demand', label='sub_region_code')
    plt.title(f'Demand Trend for Region {region_code} from {start_date} to {end_date}')

    plt.xlabel('Date')
    plt.ylabel('Demand')
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# Example usage
plot_demand_trend(full_data, "2024-01-01", "2024-04-01", 53)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Example usage
# ----> 2 plot_demand_trend(full_data, "2024-01-01", "2024-04-01", 53)
#
# NameError: name 'full_data' is not defined

# %%
import pandas as pd
full_data=pd.read_parquet('../data/transformed/full_data.parquet')
full_data
# Out:
#                        date  sub_region_code demand  temperature_2m
# 0       2024-01-02 00:00:00               53   9276          4.8085
# 1       2024-01-02 00:00:00               59   8985          4.8085
# 2       2024-01-02 00:00:00               61   1504          4.8085
# 3       2024-01-02 00:00:00               67     55          4.8085
# 4       2024-01-02 00:00:00               21  11427          4.8085
# ...                     ...              ...    ...             ...
# 758601  2025-01-01 00:00:00               64    407          0.8085
# 758602  2025-01-01 00:00:00               65   3899          0.8085
# 758603  2025-01-01 00:00:00               68   4422          0.8085
# 758604  2025-01-01 00:00:00               70   1171          0.8085
# 758605  2025-01-01 00:00:00               71   3789          0.8085
#
# [758606 rows x 4 columns]

# %%
#feature engineering on the merged data
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

def feature_engineering(data):
    data['date']= pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S')

    data['hour'] = data['date'].dt.hour
    data['day_of_week'] = data['date'].dt.dayofweek
    data['month'] = data['date'].dt.month
    data['is_weekend'] = data['day_of_week'].isin([5, 6]).astype(int)


# add (find) bank holiday (binary mask?)
    holidays = calendar().holidays(start=data['date'].min(), end=data['date'].max())
    data['is_holiday'] = data['date'].isin(holidays).astype(int)
    return data

# %%
full_data_with_FE=feature_engineering(full_data)

# %%
#full_data_with_FE.to_parquet(TRANSFORMED_DATA_DIR/f'full_data_with_FE.parquet',index=False)
#full_data_with_FE

# %%
import pandas as pd
from src.component.data_info import *
full_data_with_FE=pd.read_parquet(('../data/transformed/full_data_with_FE.parquet'))
full_data_with_FE
# Out:
#              date  sub_region_code demand  temperature_2m  hour  day_of_week  \
# 0      2024-01-02               53   9276          4.8085     0            1
# 1      2024-01-02               59   8985          4.8085     0            1
# 2      2024-01-02               61   1504          4.8085     0            1
# 3      2024-01-02               67     55          4.8085     0            1
# 4      2024-01-02               21  11427          4.8085     0            1
# ...           ...              ...    ...             ...   ...          ...
# 758601 2025-01-01               64    407          0.8085     0            2
# 758602 2025-01-01               65   3899          0.8085     0            2
# 758603 2025-01-01               68   4422          0.8085     0            2
# 758604 2025-01-01               70   1171          0.8085     0            2
# 758605 2025-01-01               71   3789          0.8085     0            2
#
#         month  is_weekend  is_holiday
# 0           1           0           0
# 1           1           0           0
# 2           1           0           0
# 3           1           0           0
# 4           1           0           0
# ...       ...         ...         ...
# 758601      1           0           1
# 758602      1           0           1
# 758603      1           0           1
# 758604      1           0           1
# 758605      1           0           1
#
# [758606 rows x 9 columns]

# %%
import tqdm
features, targets = transform_ts_data_into_features_and_target(
    full_data_with_FE,
    input_seq_len=24*28*1, # one month
    step_size=24,
)

print(f'{features.shape=}')
print(f'{targets.shape=}'),
# Out:
# 100%|██████████| 83/83 [00:15<00:00,  5.35it/s]
# features.shape=(29307, 675)
# targets.shape=(29307,)
# (None,)

# %%
tabular_data = features
tabular_data['target_demand_next_hour'] = targets

from src.paths import TRANSFORMED_DATA_DIR
tabular_data.to_parquet(TRANSFORMED_DATA_DIR / 'tabular_data_with_FE.parquet')

# %%
features_and_target = pd.read_parquet(TRANSFORMED_DATA_DIR / 'tabular_data.parquet')
features_and_target
# Out:
#        demand_previous_672_hour  demand_previous_671_hour  \
# 0                       11233.0                   10916.0
# 1                       11360.0                   11147.0
# 2                       12702.0                   12591.0
# 3                       11807.0                   12549.0
# 4                       10352.0                   11299.0
# ...                         ...                       ...
# 29302                    3221.0                    3175.0
# 29303                    3351.0                    3294.0
# 29304                    3866.0                    3723.0
# 29305                    3950.0                    3763.0
# 29306                    3771.0                    3704.0
#
#        demand_previous_670_hour  demand_previous_669_hour  \
# 0                       10704.0                   10387.0
# 1                       11114.0                   10904.0
# 2                       12286.0                   12122.0
# 3                       12565.0                   12310.0
# 4                       12290.0                   12391.0
# ...                         ...                       ...
# 29302                    3154.0                    3167.0
# 29303                    3295.0                    3338.0
# 29304                    3641.0                    3624.0
# 29305                    3589.0                    3481.0
# 29306                    3586.0                    3439.0
#
#        demand_previous_668_hour  demand_previous_667_hour  \
# 0                       10196.0                    9905.0
# 1                       10317.0                    9762.0
# 2                       11578.0                   10916.0
# 3                       12062.0                   11694.0
# 4                       12174.0                   11998.0
# ...                         ...                       ...
# 29302                    3199.0                    3274.0
# 29303                    3405.0                    3495.0
# 29304                    3635.0                    3686.0
# 29305                    3407.0                    3363.0
# 29306                    3380.0                    3353.0
#
#        demand_previous_666_hour  demand_previous_665_hour  \
# 0                        9600.0                    9254.0
# 1                        9408.0                    9056.0
# 2                       10271.0                   10111.0
# 3                       11073.0                   10446.0
# 4                       11487.0                   10970.0
# ...                         ...                       ...
# 29302                    3372.0                    3475.0
# 29303                    3659.0                    3955.0
# 29304                    3778.0                    3964.0
# 29305                    3329.0                    3396.0
# 29306                    3370.0                    3421.0
#
#        demand_previous_664_hour  demand_previous_663_hour  ...  \
# 0                        9137.0                    9045.0  ...
# 1                        8839.0                    8796.0  ...
# 2                        9917.0                   10061.0  ...
# 3                       10039.0                   10055.0  ...
# 4                       10378.0                   10148.0  ...
# ...                         ...                       ...  ...
# 29302                    3522.0                    3500.0  ...
# 29303                    4150.0                    4147.0  ...
# 29304                    4255.0                    4403.0  ...
# 29305                    3561.0                    3831.0  ...
# 29306                    3521.0                    3731.0  ...
#
#        demand_previous_6_hour  demand_previous_5_hour  demand_previous_4_hour  \
# 0                      9199.0                  9215.0                  8763.0
# 1                      9245.0                  8668.0                  8401.0
# 2                     10282.0                  9847.0                  8928.0
# 3                     11168.0                 10028.0                  9399.0
# 4                     11025.0                 11324.0                 11523.0
# ...                       ...                     ...                     ...
# 29302                  3354.0                  3464.0                  3464.0
# 29303                  3025.0                  3080.0                  3253.0
# 29304                  2998.0                  2993.0                  3047.0
# 29305                  3551.0                  3523.0                  3482.0
# 29306                  3702.0                  3695.0                  3645.0
#
#        demand_previous_3_hour  demand_previous_2_hour  demand_previous_1_hour  \
# 0                      8954.0                  8954.0                  9607.0
# 1                      8388.0                  8419.0                  8419.0
# 2                      9189.0                  9403.0                  9696.0
# 3                      9044.0                  9114.0                  8829.0
# 4                     11523.0                 11311.0                 11422.0
# ...                       ...                     ...                     ...
# 29302                  3470.0                  3425.0                  3380.0
# 29303                  3253.0                  3330.0                  3333.0
# 29304                  3226.0                  3226.0                  3303.0
# 29305                  3494.0                  3616.0                  3616.0
# 29306                  3626.0                  3672.0                  3789.0
#
#                      date  sub_region_code  temperature_2m  \
# 0     2024-01-28 02:00:00               53          0.1085
# 1     2024-01-29 01:00:00               53          0.1585
# 2     2024-01-30 00:00:00               53          1.1585
# 3     2024-01-31 00:00:00               53          6.3585
# 4     2024-01-31 23:00:00               53          2.4085
# ...                   ...              ...             ...
# 29302 2024-12-28 04:00:00               71         -1.0415
# 29303 2024-12-29 03:00:00               71         -2.3415
# 29304 2024-12-30 02:00:00               71          2.2085
# 29305 2024-12-31 01:00:00               71          1.6085
# 29306 2025-01-01 00:00:00               71          0.8085
#
#        target_demand_next_hour
# 0                      10318.0
# 1                       8861.0
# 2                       9696.0
# 3                       9193.0
# 4                      11696.0
# ...                        ...
# 29302                   3322.0
# 29303                   3307.0
# 29304                   3325.0
# 29305                   3629.0
# 29306                   3789.0
#
# [29307 rows x 676 columns]

# %%
features = features_and_target.drop(columns=['target_demand_next_hour'])
targets = features_and_target['target_demand_next_hour']
